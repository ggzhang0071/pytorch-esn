# %%
import TorchESN as TN
TN.torch_ESN([0.6,0.3,0.001])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-1dcebc753b9e> in <module>
#       1 import TorchESN as TN
# ----> 2 TN.torch_ESN([0.6,0.3,0.001])
#
# /git/hilbertNN/pytorch-esn/examples/TorchESN.py in torch_ESN(parameters)
#      45     model.to(device)
#      46
# ---> 47     model(trX, washout, None, trY_flat)
#      48     model.fit()
#      49 #     set_trace()
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /git/hilbertNN/pytorch-esn/torchesn/nn/echo_state_network.py in forward(self, input, washout, h_0, target)
# ...
